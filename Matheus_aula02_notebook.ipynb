# %% [markdown]
# # ⛰ ***Exercícios — Aula 2***

# %% [markdown]
# ## Questão 1 📝
#
# Escreva um programa que leia N números e exiba uma mensagem informando se cada número é positivo, negativo ou zero.
#
# Use um loop infinito com condição de parada: quando o usuário digitar `"pare"`, o programa encerra.

# %%
while True:
  n = input()
  if n == "pare":
    break
  if int(n) > 0:
    print("Maior que 0")
  elif int(n) < 0:
    print("Menor que 0")
  else:
    print("Igual a 0")
# Out:
# Running cells with 'Python 3.12.9' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/mathe/AppData/Local/Programs/Python/Python312/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ### 💡 Dica:
#
# *Utilize somente se necessário — tente resolver primeiro sozinho!*

# %% [markdown]
# *O `input()` sempre retorna string, lembre-se de converter para `int` antes de comparar com `>` ou `<`.*

# %% [markdown]
# ## Questão 2 📝
#
# Faça um programa que peça ao usuário para digitar senhas até que ele acerte a senha correta.
#
# A senha predefinida é: `"trilhaaula2"`
#
# Após acertar, mostre quantas tentativas incorretas foram necessárias.

# %%
counter = 0
while True:
  senha = str(input())
  if senha == "trilhaaula2":
    break
  counter += 1
print(f"{counter} tentativa(s) incorreta(s)")
# Out:
# oi
# trilhaaula2
# 1 tentativas incorretas

# %% [markdown]
# ### 💡 Dica:
#
# *Utilize somente se necessário — tente resolver primeiro sozinho!*

# %% [markdown]
# *Quantas vezes o usuário vai errar? Pense em qual loop faz mais sentido aqui. Um contador externo pode te ajudar a registrar os erros.*

# %% [markdown]
# ## Questão 3 📝
#
# Crie um programa que peça um número ao usuário e determine se ele é primo.
#
# *Lembrete: número primo é divisível apenas por 1 e por ele mesmo. O número 1 **não** é primo.*

# %%
number = int(input())
divisores = 0

for i in range(1, number+1):
  if number % i == 0:
    divisores += 1

if divisores == 2:
  print("Primo")
else:
  print("Nao eh primo")
# Out:
# 4
# Nao eh primo

# %% [markdown]
# ### 💡 Dica:
#
# *Utilize somente se necessário — tente resolver primeiro sozinho!*

# %% [markdown]
# *Use `%` para testar divisores entre 2 e `numero - 1`. Encontrou algum? Não é primo. Chegou ao fim sem encontrar? É primo.*
#
# *Curiosidade: o bloco `else` de um `for` só executa quando o loop termina **sem** `break`.*

# %% [markdown]
# ## Questão 4 📝
#
# Escreva um programa que exiba a tabuada completa de 1 a 10.
#
# **Exemplo de saída esperada (trecho):**
# ```
# Tabuada do 1:
# 1 x 1 = 1
# 1 x 2 = 2
# ...
# ```

# %%
def tabuada(number):
  print(f"Tabuada do {number}:")
  for i in range(1, 11):
    produto = number * i
    print(f"{number} x {i} = {produto}")

for i in range(1, 11):
  tabuada(i)
# Out:
# Tabuada do 1:
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10
# Tabuada do 2:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
# Tabuada do 3:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
# Tabuada do 4:
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
# Tabuada do 5:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# Tabuada do 6:
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
# Tabuada do 7:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
# Tabuada do 8:
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 8 x 10 = 80
# Tabuada do 9:
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90
# Tabuada do 10:
# 10 x 1 = 10
# 10 x 2 = 20
# 10 x 3 = 30
# 10 x 4 = 40
# 10 x 5 = 50
# 10 x 6 = 60
# 10 x 7 = 70
# 10 x 8 = 80
# 10 x 9 = 90
# 10 x 10 = 100

# %% [markdown]
# ### 💡 Dica:
#
# *Utilize somente se necessário — tente resolver primeiro sozinho!*

# %% [markdown]
# *Você vai precisar de um loop dentro do outro. Pense: o externo decide **qual** tabuada; o interno faz as multiplicações.*

# %% [markdown]
# ## Questão 5 📝
#
# Crie uma função chamada `calcular_media(n1, n2, n3)` que recebe três notas, calcula a média e **retorna** o resultado.
#
# Depois, chame a função com três valores e imprima a média usando f-string com 2 casas decimais.

# %%
def calcular_media(n1, n2, n3):
  media = (n1+n2+n3)/3
  return media

n1 = int(input())
n2 = int(input())
n3 = int(input())

print(f"Media entre: {n1}, {n2}, {n3}: {calcular_media(n1, n2, n3):.2f}")
# Out:
# 10
# 2
# 13
# Media entre: 10, 2, 13: 8.33

# %% [markdown]
# ### 💡 Dica:
#
# *Utilize somente se necessário — tente resolver primeiro sozinho!*

# %% [markdown]
# *`Média = (n1 + n2 + n3) / 3`. Para exibir com 2 casas decimais: `f"{variavel:.2f}"`.*

# %% [markdown]
# ## Questão 6 📝
#
# Crie uma função chamada `par_ou_impar(numero)` que recebe um número inteiro e **imprime** se ele é par ou ímpar.
#
# *Atenção: esta função não precisa retornar nada.*
#
# Depois, chame a função com 3 números diferentes.

# %%
def par_ou_impar(num):
  if num % 2 == 0:
    print("par")
  else:
    print("impar")

n1 = int(input())
par_ou_impar(n1)
n2 = int(input())
par_ou_impar(n2)
n3 = int(input())
par_ou_impar(n3)
# Out:
# 20
# par
# 13
# impar
# 0
# par

# %% [markdown]
# ### 💡 Dica:
#
# *Utilize somente se necessário — tente resolver primeiro sozinho!*

# %% [markdown]
# *`numero % 2` retorna o resto da divisão por 2 — o que esse valor diz sobre o número?*
#
# *Funções sem `return` são chamadas de **funções nulas** e retornam `None` implicitamente.*

# %% [markdown]
# ## Questão 7 📝
#
# Crie uma função chamada `calcular_fatorial(n)` que recebe um número inteiro positivo e **retorna** seu fatorial usando um loop `for`.
#
# *Lembrete: fatorial de n = 1 × 2 × 3 × ... × n. Por convenção, fatorial de 0 é 1.*
#
# Depois, chame a função para calcular o fatorial de 5 e imprima o resultado.

# %%
def calcular_fatorial(n):
  if n == 0:
      return 0
  fat = 1
  for i in range(2, n+1):
    fat *= i
  return fat

print(calcular_fatorial(5))
# Out:
# 120

# %% [markdown]
# ### 💡 Dica:
#
# *Utilize somente se necessário — tente resolver primeiro sozinho!*

# %% [markdown]
# *Inicie `resultado = 1` (elemento neutro da multiplicação) e vá multiplicando a cada iteração. Qual `range()` percorre de 1 até n **inclusive**?*
